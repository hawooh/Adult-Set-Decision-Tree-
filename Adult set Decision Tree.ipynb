# %%
import os
os.chdir("C:\\Users\\OLAOYE OLUWATOBILOBA\\Documents")

# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("adult_dataset.csv")
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=32561, step=1)

# %%
#Describe shows the statiscal summary of a Data set
data.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
data.values
# Out:
# array([[90, '?', 77053, ..., 40, 'United-States', '<=50K'],
#        [82, 'Private', 132870, ..., 18, 'United-States', '<=50K'],
#        [66, '?', 186061, ..., 40, 'United-States', '<=50K'],
#        ...,
#        [40, 'Private', 154374, ..., 40, 'United-States', '>50K'],
#        [58, 'Private', 151910, ..., 40, 'United-States', '<=50K'],
#        [22, 'Private', 201490, ..., 20, 'United-States', '<=50K']],
#       dtype=object)

# %%
#Transposing your Data

data.T
# Out:
#                         0                1              2      \
# age                        90               82             66
# workclass                   ?          Private              ?
# fnlwgt                  77053           132870         186061
# education             HS-grad          HS-grad   Some-college
# education.num               9                9             10
# marital.status        Widowed          Widowed        Widowed
# occupation                  ?  Exec-managerial              ?
# relationship    Not-in-family    Not-in-family      Unmarried
# race                    White            White          Black
# sex                    Female           Female         Female
# capital.gain                0                0              0
# capital.loss             4356             4356           4356
# hours.per.week             40               18             40
# native.country  United-States    United-States  United-States
# ...

# %%
#Sorting of Data by axis
data.sort_index(axis=1, ascending=False)
# Out:
#       workclass     sex   relationship   race         occupation  \
# 0             ?  Female  Not-in-family  White                  ?
# 1       Private  Female  Not-in-family  White    Exec-managerial
# 2             ?  Female      Unmarried  Black                  ?
# 3       Private  Female      Unmarried  White  Machine-op-inspct
# 4       Private  Female      Own-child  White     Prof-specialty
# ...         ...     ...            ...    ...                ...
# 32556   Private    Male  Not-in-family  White    Protective-serv
# 32557   Private  Female           Wife  White       Tech-support
# 32558   Private    Male        Husband  White  Machine-op-inspct
# 32559   Private  Female      Unmarried  White       Adm-clerical
# 32560   Private    Male      Own-child  White       Adm-clerical
#
#       native.country      marital.status income  hours.per.week  fnlwgt  \
# 0      United-States             Widowed  <=50K              40   77053
# ...

# %%
#Sorting by values
data.sort_values(by='sex')
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       90                 ?   77053       HS-grad              9
# 11105   22           Private  122272       HS-grad              9
# 11109   33           Private  348416       HS-grad              9
# 11110   31           Private  379046       HS-grad              9
# 24814   18           Private  163787       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 12689   52           Private  162576    Assoc-acdm             12
# 12688   52           Private  329733  Some-college             10
# 12686   36  Self-emp-not-inc  153976       HS-grad              9
# 12702   36  Self-emp-not-inc  160120     Bachelors             13
# 32560   22           Private  201490       HS-grad              9
#
#            marital.status         occupation   relationship  \
# 0                 Widowed                  ?  Not-in-family
# ...

# %%
#Selection using Pandas .at, .iat, .loc, .iloc, .ix

# %%
#getting a single column in form of Series
data["sex"]
# Out:
# 0        Female
# 1        Female
# 2        Female
# 3        Female
# 4        Female
#           ...
# 32556      Male
# 32557    Female
# 32558      Male
# 32559    Female
# 32560      Male
# Name: sex, Length: 32561, dtype: object

# %%
#selecting [] which slices the rows

data[0:3]
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
# 2                ?      Unmarried  Black  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#To define Categorical Variables to declare Objects in the Datasets
data_categorical=data.select_dtypes(include=["object"])

# %%
#getting the total Sum of Objects that needs to be corrected
data_categorical.apply(lambda x:x=="?",axis=0).sum()
# Out:
# workclass         1836
# education            0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# native.country     583
# income               0
# dtype: int64

# %%
data=data[data.workclass!="?"]

# %%
data=data[data["native.country"]!="?"]

# %%
data=data[data.occupation!="?"]

# %%
data_categorical=data.select_dtypes(include=["object"])

# %%
data_categorical.head()
# Out:
#   workclass     education marital.status         occupation   relationship  \
# 1   Private       HS-grad        Widowed    Exec-managerial  Not-in-family
# 3   Private       7th-8th       Divorced  Machine-op-inspct      Unmarried
# 4   Private  Some-college      Separated     Prof-specialty      Own-child
# 5   Private       HS-grad       Divorced      Other-service      Unmarried
# 6   Private          10th      Separated       Adm-clerical      Unmarried
#
#     race     sex native.country income
# 1  White  Female  United-States  <=50K
# 3  White  Female  United-States  <=50K
# 4  White  Female  United-States  <=50K
# 5  White  Female  United-States  <=50K
# 6  White    Male  United-States  <=50K

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data_categorical=data_categorical.apply(le.fit_transform)

# %%
data_categorical.head()
# Out:
#    workclass  education  marital.status  occupation  relationship  race  sex  \
# 1          2         11               6           3             1     4    0
# 3          2          5               0           6             4     4    0
# 4          2         15               5           9             3     4    0
# 5          2         11               0           7             4     4    0
# 6          2          0               5           0             4     4    1
#
#    native.country  income
# 1              38       0
# 3              38       0
# 4              38       0
# 5              38       0
# 6              38       0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(data.shape)
# Out:
# (30162, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 1 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  int64
#  1   workclass       30162 non-null  object
#  2   fnlwgt          30162 non-null  int64
#  3   education       30162 non-null  object
#  4   education.num   30162 non-null  int64
#  5   marital.status  30162 non-null  object
#  6   occupation      30162 non-null  object
#  7   relationship    30162 non-null  object
#  8   race            30162 non-null  object
#  9   sex             30162 non-null  object
#  10  capital.gain    30162 non-null  int64
#  11  capital.loss    30162 non-null  int64
#  12  hours.per.week  30162 non-null  int64
#  13  native.country  30162 non-null  object
#  14  income          30162 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data=data.drop(data_categorical.columns,axis=1)

# %%
data=pd.concat([data,data_categorical],axis=1)

# %%
data.head()
# Out:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1   82  132870              9             0          4356              18
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
# 5   34  216864              9             0          3770              45
# 6   38  150601              6             0          3770              40
#
#    workclass  education  marital.status  occupation  relationship  race  sex  \
# 1          2         11               6           3             1     4    0
# 3          2          5               0           6             4     4    0
# 4          2         15               5           9             3     4    0
# 5          2         11               0           7             4     4    0
# 6          2          0               5           0             4     4    1
#
#    native.country  income
# 1              38       0
# ...

# %%
data["income"]=data["income"].astype("category")
data.head()
# Out:
#    age  fnlwgt  education.num  capital.gain  capital.loss  hours.per.week  \
# 1   82  132870              9             0          4356              18
# 3   54  140359              4             0          3900              40
# 4   41  264663             10             0          3900              40
# 5   34  216864              9             0          3770              45
# 6   38  150601              6             0          3770              40
#
#    workclass  education  marital.status  occupation  relationship  race  sex  \
# 1          2         11               6           3             1     4    0
# 3          2          5               0           6             4     4    0
# 4          2         15               5           9             3     4    0
# 5          2         11               0           7             4     4    0
# 6          2          0               5           0             4     4    1
#
#    native.country income
# 1              38      0
# ...

# %%
X=data.drop("income",axis=1)
y=data["income"]

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,ytrain,Xtest,ytest=train_test_split(X,y, test_size=0.2, random_state=0)

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=0)
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()

# %%
tree.fit(Xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=tree.predict(Xtest)

print(accuracy_score(ytest,y_pred))
# Out:
# 0.8078899386706447
