# %% [markdown]
# <a href="https://colab.research.google.com/github/hawooh/Adult-Set-Decision-Tree-/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 21.8 MB/s eta 0:00:00
# ...

# %%
from faker import Faker
import pandas as pd
import numpy as np

# Initialize Faker instance
fake = Faker()

# Number of records to generate
num_records = 10000

# 1. Predictive Modeling for Project Scope
def generate_project_scope_data():
    project_types = ['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair', 'Flooring']
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Project_Type': [np.random.choice(project_types) for _ in range(num_records)],
        'Budget': [round(np.random.uniform(5000, 20000), 2) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'User_Age': [np.random.randint(25, 65) for _ in range(num_records)],
        'Project_Preference': [fake.text(max_nb_chars=100) for _ in range(num_records)]
    }

# 2. Customer Segmentation
def generate_customer_segmentation_data():
    return {
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Age': [np.random.randint(18, 75) for _ in range(num_records)],
        'Income': [round(np.random.uniform(30000, 150000), 2) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Family_Size': [np.random.randint(1, 6) for _ in range(num_records)],
        'Home_Ownership': [np.random.choice(['Own', 'Rent']) for _ in range(num_records)],
    }

# 3. Recommendation Systems
def generate_recommendation_data():
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Last_Visited_Products': [fake.word() for _ in range(num_records)],
        'Recent_Purchase': [fake.word() for _ in range(num_records)],
        'Preferred_Material': [np.random.choice(['Wood', 'Granite', 'Marble', 'Tile', 'Concrete']) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
    }

# 4. Lead Scoring
def generate_lead_scoring_data():
    return {
        'Lead_ID': [fake.uuid4() for _ in range(num_records)],
        'Lead_Source': [np.random.choice(['Website', 'Referral', 'Advertisement', 'Social Media']) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Urgency_Level': [np.random.choice(['High', 'Medium', 'Low']) for _ in range(num_records)],
        'Contact_Method': [np.random.choice(['Phone', 'Email', 'Text']) for _ in range(num_records)],
        'Lead_Quality': [np.random.choice(['Hot', 'Warm', 'Cold']) for _ in range(num_records)],
    }

# 5. Price Optimization
def generate_price_optimization_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Price_Quoted': [round(np.random.uniform(5000, 30000), 2) for _ in range(num_records)],
        'Materials_Cost': [round(np.random.uniform(1000, 10000), 2) for _ in range(num_records)],
        'Labor_Cost': [round(np.random.uniform(2000, 15000), 2) for _ in range(num_records)],
        'Markup': [round(np.random.uniform(10, 50), 2) for _ in range(num_records)],
    }

# 6. Project Timeline Prediction
def generate_project_timeline_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Scope_Complexity': [np.random.choice(['Simple', 'Moderate', 'Complex']) for _ in range(num_records)],
        'Materials_Delivery_Time': [np.random.randint(3, 10) for _ in range(num_records)],
        'Labor_Availability': [np.random.choice(['Available', 'Limited', 'Not Available']) for _ in range(num_records)],
        'Estimated_Completion_Time': [np.random.randint(1, 30) for _ in range(num_records)],
    }

# 7. Churn Prediction
def generate_churn_prediction_data():
    return {
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Last_Active': [fake.date_this_year() for _ in range(num_records)],
        'Engagement_Score': [np.random.uniform(0, 1) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Feedback_Score': [np.random.randint(1, 6) for _ in range(num_records)],
        'Churn_Risk': [np.random.choice(['Low', 'Medium', 'High']) for _ in range(num_records)],
    }

# 8. Demand Forecasting
def generate_demand_forecasting_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Seasonality': [np.random.choice(['Winter', 'Spring', 'Summer', 'Fall']) for _ in range(num_records)],
        'Demand_Forecast': [np.random.randint(10, 100) for _ in range(num_records)],
    }

# 9. Text Analytics for Feedback
def generate_feedback_data():
    return {
        'Feedback_ID': [fake.uuid4() for _ in range(num_records)],
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Feedback_Text': [fake.text(max_nb_chars=200) for _ in range(num_records)],
        'Rating': [np.random.randint(1, 6) for _ in range(num_records)],
        'Feedback_Type': [np.random.choice(['Complaint', 'Suggestion', 'Compliment']) for _ in range(num_records)],
    }

# 10. Image Recognition for Design Preferences
def generate_image_recognition_data():
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Uploaded_Image': [fake.image_url() for _ in range(num_records)],
        'Suggested_Design': [np.random.choice(['Modern', 'Contemporary', 'Classic', 'Rustic']) for _ in range(num_records)],
        'Design_Preference': [np.random.choice(['Minimalist', 'Maximalist', 'Functional']) for _ in range(num_records)],
    }

# Example: Generate the data
project_scope_data = pd.DataFrame(generate_project_scope_data())
customer_segmentation_data = pd.DataFrame(generate_customer_segmentation_data())
recommendation_data = pd.DataFrame(generate_recommendation_data())
lead_scoring_data = pd.DataFrame(generate_lead_scoring_data())
price_optimization_data = pd.DataFrame(generate_price_optimization_data())
project_timeline_data = pd.DataFrame(generate_project_timeline_data())
churn_prediction_data = pd.DataFrame(generate_churn_prediction_data())
demand_forecasting_data = pd.DataFrame(generate_demand_forecasting_data())
feedback_data = pd.DataFrame(generate_feedback_data())
image_recognition_data = pd.DataFrame(generate_image_recognition_data())

# Example output
print(project_scope_data.head())
print(customer_segmentation_data.head())
print(recommendation_data.head())
# Out:
#                                 User_ID     Project_Type    Budget  \
# 0  35db0bac-c9c9-4cd2-8ced-c19ac424d544  Kitchen Remodel  18753.63
# 1  92025388-4851-4c38-8dcc-8b36ed87357a         Flooring  15654.07
# 2  80f11660-d26f-4a88-8056-33e4b159f180  Kitchen Remodel  18834.88
# 3  1e4b115d-3822-410b-99d2-4fe6f9c00f94  Kitchen Remodel   6554.04
# 4  9bf7306a-810a-4b4d-9f30-2d13f849a968      Roof Repair  14673.45
#
#               Location  User_Age  \
# 0           Shellyview        27
# 1      South Jamesland        39
# 2            New Barry        59
# 3  North Mackenzieside        31
# 4          Tristanstad        25
#
#                                   Project_Preference
# 0  Mr information store station seem painting fea...
# 1  Media soldier crime any energy.\nScientist sho...
# 2  Statement example part per catch value. Third ...
# 3                    Enough drop condition language.
# 4  Industry much power party realize assume. Heal...
# ...

# %%
import pandas as pd
from faker import Faker
import numpy as np

# Initialize Faker instance
fake = Faker()

# Number of records to generate
num_records = 1000

# 1. Predictive Modeling for Project Scope
def generate_project_scope_data():
    project_types = ['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair', 'Flooring']
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Project_Type': [np.random.choice(project_types) for _ in range(num_records)],
        'Budget': [round(np.random.uniform(5000, 20000), 2) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'User_Age': [np.random.randint(25, 65) for _ in range(num_records)],
        'Project_Preference': [fake.text(max_nb_chars=100) for _ in range(num_records)]
    }

# 2. Customer Segmentation
def generate_customer_segmentation_data():
    return {
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Age': [np.random.randint(18, 75) for _ in range(num_records)],
        'Income': [round(np.random.uniform(30000, 150000), 2) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Family_Size': [np.random.randint(1, 6) for _ in range(num_records)],
        'Home_Ownership': [np.random.choice(['Own', 'Rent']) for _ in range(num_records)],
    }

# 3. Recommendation Systems
def generate_recommendation_data():
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Last_Visited_Products': [fake.word() for _ in range(num_records)],
        'Recent_Purchase': [fake.word() for _ in range(num_records)],
        'Preferred_Material': [np.random.choice(['Wood', 'Granite', 'Marble', 'Tile', 'Concrete']) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
    }

# 4. Lead Scoring
def generate_lead_scoring_data():
    return {
        'Lead_ID': [fake.uuid4() for _ in range(num_records)],
        'Lead_Source': [np.random.choice(['Website', 'Referral', 'Advertisement', 'Social Media']) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Urgency_Level': [np.random.choice(['High', 'Medium', 'Low']) for _ in range(num_records)],
        'Contact_Method': [np.random.choice(['Phone', 'Email', 'Text']) for _ in range(num_records)],
        'Lead_Quality': [np.random.choice(['Hot', 'Warm', 'Cold']) for _ in range(num_records)],
    }

# 5. Price Optimization
def generate_price_optimization_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Price_Quoted': [round(np.random.uniform(5000, 30000), 2) for _ in range(num_records)],
        'Materials_Cost': [round(np.random.uniform(1000, 10000), 2) for _ in range(num_records)],
        'Labor_Cost': [round(np.random.uniform(2000, 15000), 2) for _ in range(num_records)],
        'Markup': [round(np.random.uniform(10, 50), 2) for _ in range(num_records)],
    }

# 6. Project Timeline Prediction
def generate_project_timeline_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Scope_Complexity': [np.random.choice(['Simple', 'Moderate', 'Complex']) for _ in range(num_records)],
        'Materials_Delivery_Time': [np.random.randint(3, 10) for _ in range(num_records)],
        'Labor_Availability': [np.random.choice(['Available', 'Limited', 'Not Available']) for _ in range(num_records)],
        'Estimated_Completion_Time': [np.random.randint(1, 30) for _ in range(num_records)],
    }

# 7. Churn Prediction
def generate_churn_prediction_data():
    return {
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Last_Active': [fake.date_this_year() for _ in range(num_records)],
        'Engagement_Score': [np.random.uniform(0, 1) for _ in range(num_records)],
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Feedback_Score': [np.random.randint(1, 6) for _ in range(num_records)],
        'Churn_Risk': [np.random.choice(['Low', 'Medium', 'High']) for _ in range(num_records)],
    }

# 8. Demand Forecasting
def generate_demand_forecasting_data():
    return {
        'Project_Type': [np.random.choice(['Kitchen Remodel', 'Bathroom Remodel', 'Living Room Update', 'Roof Repair']) for _ in range(num_records)],
        'Location': [fake.city() for _ in range(num_records)],
        'Seasonality': [np.random.choice(['Winter', 'Spring', 'Summer', 'Fall']) for _ in range(num_records)],
        'Demand_Forecast': [np.random.randint(10, 100) for _ in range(num_records)],
    }

# 9. Text Analytics for Feedback
def generate_feedback_data():
    return {
        'Feedback_ID': [fake.uuid4() for _ in range(num_records)],
        'Customer_ID': [fake.uuid4() for _ in range(num_records)],
        'Feedback_Text': [fake.text(max_nb_chars=200) for _ in range(num_records)],
        'Rating': [np.random.randint(1, 6) for _ in range(num_records)],
        'Feedback_Type': [np.random.choice(['Complaint', 'Suggestion', 'Compliment']) for _ in range(num_records)],
    }

# 10. Image Recognition for Design Preferences
def generate_image_recognition_data():
    return {
        'User_ID': [fake.uuid4() for _ in range(num_records)],
        'Uploaded_Image': [fake.image_url() for _ in range(num_records)],
        'Suggested_Design': [np.random.choice(['Modern', 'Contemporary', 'Classic', 'Rustic']) for _ in range(num_records)],
        'Design_Preference': [np.random.choice(['Minimalist', 'Maximalist', 'Functional']) for _ in range(num_records)],
    }

# Example: Generate the data and save to CSV
def save_data_to_csv():
    project_scope_data = pd.DataFrame(generate_project_scope_data())
    customer_segmentation_data = pd.DataFrame(generate_customer_segmentation_data())
    recommendation_data = pd.DataFrame(generate_recommendation_data())
    lead_scoring_data = pd.DataFrame(generate_lead_scoring_data())
    price_optimization_data = pd.DataFrame(generate_price_optimization_data())
    project_timeline_data = pd.DataFrame(generate_project_timeline_data())
    churn_prediction_data = pd.DataFrame(generate_churn_prediction_data())
    demand_forecasting_data = pd.DataFrame(generate_demand_forecasting_data())
    feedback_data = pd.DataFrame(generate_feedback_data())
    image_recognition_data = pd.DataFrame(generate_image_recognition_data())

    # Saving data to CSV
    project_scope_data.to_csv('project_scope_data.csv', index=False)
    customer_segmentation_data.to_csv('customer_segmentation_data.csv', index=False)
    recommendation_data.to_csv('recommendation_data.csv', index=False)
    lead_scoring_data.to_csv('lead_scoring_data.csv', index=False)
    price_optimization_data.to_csv('price_optimization_data.csv', index=False)
    project_timeline_data.to_csv('project_timeline_data.csv', index=False)
    churn_prediction_data.to_csv('churn_prediction_data.csv', index=False)
    demand_forecasting_data.to_csv('demand_forecasting_data.csv', index=False)
    feedback_data.to_csv('feedback_data.csv', index=False)
    image_recognition_data.to_csv('image_recognition_data.csv', index=False)

# Call the function to generate and save data
save_data_to_csv()

# %%
from google.colab import files

# List of CSV files generated
csv_files = [
    'project_scope_data.csv',
    'customer_segmentation_data.csv',
    'recommendation_data.csv',
    'lead_scoring_data.csv',
    'price_optimization_data.csv',
    'project_timeline_data.csv',
    'churn_prediction_data.csv',
    'demand_forecasting_data.csv',
    'feedback_data.csv',
    'image_recognition_data.csv',
]

# Download each file
for file in csv_files:
    files.download(file)
